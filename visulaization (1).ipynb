# %% [markdown]
# # Information about the Dataset

# %% [markdown]
# ## This dataset contains the details and features of different models of different Softdrinks manufacturers. The dataset contains almost 1260observations for which 7 variables that provides informations of each of the observations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
softdrinks=pd.read_csv("D://downloads//larisa.csv")

# %%
softdrinks
# Out:
#             date    shop        brand container  quantity capacity     sales
# 0     31-01-2012  shop_5  kinder-cola     glass      7496    500ml  10363.34
# 1     31-01-2012  shop_5  kinder-cola   plastic      5330    1.5lt  16126.87
# 2     31-01-2012  shop_5  kinder-cola       can     19572    330ml   8952.22
# 3     31-01-2012  shop_5   adult-cola     glass     14887    500ml  15714.30
# 4     31-01-2012  shop_5   adult-cola   plastic      9126    1.5lt  25811.66
# ...          ...     ...          ...       ...       ...      ...       ...
# 1255  31-12-2018  shop_5       gazoza   plastic     22136    1.5lt  27621.80
# 1256  31-12-2018  shop_5       gazoza       can     43513    330ml  13289.41
# 1257  31-12-2018  shop_5  lemon-boost     glass     26496    500ml  18917.76
# 1258  31-12-2018  shop_5  lemon-boost   plastic     16548    1.5lt  32329.90
# 1259  31-12-2018  shop_5  lemon-boost       can     23270    330ml  14560.09
#
# [1260 rows x 7 columns]

# %%
softdrinks.describe()
# Out:
#            quantity         sales
# count   1260.000000   1260.000000
# mean   23484.860317  21878.885849
# std    12738.198537  10580.571340
# min     3745.000000   4370.730000
# 25%    13938.250000  13960.135000
# 50%    20381.500000  19754.520000
# 75%    31175.250000  27631.717500
# max    75070.000000  73616.800000

# %% [markdown]
# ### In this dataset ,it shows us the basic statistical data of dataset,Like Count, Mean, STD, min, 25th percentile, 50th percentile, 75th percentile and max functions

# %%
plt.boxplot(softdrinks['sales'])
plt.show()

# %% [markdown]
# ### Boxplot for 'sales'' variable is shown from the dataset, where there are outliers in the 70000,Here we can see that the boxplot lies between '15000' to '30000'

# %%
plt.boxplot(softdrinks['sales'])
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Here log has been taken for 'Y' axis for the better representaion of the boxplot

# %%
sns.distplot(softdrinks['sales'])
plt.show()
# Out:
# D:\anaconda-navigater\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Distplot is created for the variable "sales" where the data has its peak value from 10000 to 20000, the value decrease on the range of 20000 to 40000.

# %%
plt.scatter(softdrinks['sales'],softdrinks['quantity'])
plt.xticks(color='red',fontweight='bold',fontsize='12',rotation='90')
plt.show()

# %% [markdown]
# ### In this scatterplot, variables ''sales'' and ''quantity'', there is outlier lies in 70000 in yaxis, the maximum value of data in the dataset is occured between the values of (5000 to 45000) in x-axis.

# %%
x=list(softdrinks.iloc[:3])
y=list(softdrinks.iloc[:4])
plt.bar(x,y,color='r')
plt.title("sales vs quantity")
plt.xlabel('sales')
plt.ylabel('quantity')
plt.xticks(color='r',fontweight='bold',fontsize='12',rotation='85',horizontalalignment='center')
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ### we have changed the fontsize,fontweight, horizontal alignment,color and rotation of displayed barplot.¶

# %%
plt.hist(softdrinks['quantity'])
plt.show()

# %% [markdown]
# ### Here histogram is created for variable 'quantity' to get a better understanding of the dataset. it shows that there are values lies bewteeen 5000 to 9000 and seperately outliers are lieing in 70000 .¶

# %%
sns.distplot(softdrinks['sales'])
plt.show()
# Out:
# D:\anaconda-navigater\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Most of the softdrinks sold between the 3000 to 40000.but highest number of sales is 80000 mobiles.

# %%
sns.distplot(softdrinks['sales'],hist='Fales')
plt.show()
# Out:
# D:\anaconda-navigater\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### by using the hist function and giving false it show us only the line in the data and it does not displays the bar in the plots

# %%
plt.subplot(2,2,1)
plt.title('sales')
sns.distplot(softdrinks['sales'])

plt.subplot(2,2,2)
plt.title('quantity')
sns.distplot(softdrinks['quantity'])

plt.tight_layout()
# Out:
# D:\anaconda-navigater\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda-navigater\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### We have created a subplots for two varivables "sales,quantity"

# %%
sns.jointplot('sales','quantity',softdrinks)
plt.show()
# Out:
# D:\anaconda-navigater\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### In this joinplot we have chosen a two variables "sales" and "quantity"

# %%
softdrinks=softdrinks[(softdrinks.sales<15000)&(softdrinks.quantity<30000)]
sns.jointplot('sales','quantity',softdrinks)
plt.show()
# Out:
# D:\anaconda-navigater\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### In this joinplot we have chosen a certain value and condition for the two variables "sales"<15000 and "quantity"<30000.

# %%
softdrinks=softdrinks[(softdrinks.sales<15000)&(softdrinks.quantity<30000)]
sns.jointplot('sales','quantity',softdrinks)
sns.jointplot(x='sales',y='quantity',data=softdrinks,kind='hex',color='r')
plt.show()
# Out:
# D:\anaconda-navigater\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.hist(softdrinks['sales'])
plt.yscale('log')
plt.show()

# %% [markdown]
# ### By taking the log scale for the histogram , it displays us there data present around 4500 to 14000 went taking log scale it displays as a clear view of data compared to normal histogram.

# %%
sns.boxplot(y=softdrinks['sales'])
plt.title('sales')
plt.show()

# %% [markdown]
# ### We have displayed the data set in the vertical view in order to have clear view of understanding about dataset.
