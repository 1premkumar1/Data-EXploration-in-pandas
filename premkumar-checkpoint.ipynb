# %% [markdown]
# # DATA EXPLORATION USING PANDAS

# %%
import pandas as pd

# %%
sample=pd.read_csv('D://pyton//flipkart.csv')

# %% [markdown]
# ## We use pd.read_csv function to read the dataset in the PYTHON

# %% [markdown]
# We use pd.read_csv function to read the dataset in the PYTHON

# %% [markdown]
# ## About The Dataset

# %%
sample
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# ...

# %%
sample.shape
# Out:
# (20000, 10)

# %% [markdown]
# ##### It shows the number of Observations and Variables in the dataset.

# %%
sample.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_name', 'product_category_tree',
#        'retail_price', 'discounted_price', 'is_FK_Advantage_product',
#        'product_rating', 'overall_rating', 'brand'],
#       dtype='object')

# %% [markdown]
# ##### Sample.columns function is used to display the column name

# %%
sample.index
# Out:
# RangeIndex(start=0, stop=20000, step=1)

# %% [markdown]
# ##### This is used to show the Range Index Of the Dataset

# %%
sample.sort_values(['crawl_timestamp'],ascending= True)
# Out:
#                                uniq_id            crawl_timestamp  \
# 6515  f386f28cbc2ca9a63b5dc7a8fe6d5098  2015-12-01 06:13:00 +0000
# 6170  7d1adfefeedb1e320edf369b2758e042  2015-12-01 06:13:00 +0000
# 6171  3c0f6251ba3ffe5d489e5f14a3d3e2ea  2015-12-01 06:13:00 +0000
# 6172  aae26022cadbb64ba64df432568ba938  2015-12-01 06:13:00 +0000
# 6173  00f56d155dc1c8cbe410e92169cc6dc6  2015-12-01 06:13:00 +0000
# ...                                ...                        ...
# 912   a47d2e0bba55652f3f5b3831f7dc6cb3  2016-06-28 08:45:50 +0000
# 911   51f9d0a08ca3651e477af836656b0bee  2016-06-28 08:45:50 +0000
# 910   46648b54c8bcf683369be053be1bf987  2016-06-28 08:45:50 +0000
# 909   ad6210c447cbb2e5d7ff622bee497a2f  2016-06-28 08:45:50 +0000
# 908   017b4baf09ba01799cb01ecc96356f26  2016-06-28 08:45:50 +0000
#
#                                            product_name  \
# 6515                     Denver Caliber,Pride Combo Set
# 6170                    Kolkata Knight Riders Combo Set
# ...

# %% [markdown]
# ##### Sample.sort_values is used values and arranging it using the ascending function

# %%
sample.head
# Out:
# <bound method NDFrame.head of                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# ...

# %% [markdown]
# ##### By using this function this displays first five data in the dataset.

# %%
sample.tail
# Out:
# <bound method NDFrame.tail of                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# ...

# %% [markdown]
# ##### To display the last five data in the data we use sample.tail function.

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_name             20000 non-null  object
#  3   product_category_tree    20000 non-null  object
#  4   retail_price             19922 non-null  float64
#  5   discounted_price         19922 non-null  float64
#  6   is_FK_Advantage_product  20000 non-null  bool
#  7   product_rating           20000 non-null  object
#  8   overall_rating           20000 non-null  object
#  9   brand                    14136 non-null  object
# dtypes: bool(1), float64(2), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# ##### By using the sample.info function it shows the Variables,non null count and Dtype in the dataset.

# %%
sample.describe()
# Out:
#         retail_price  discounted_price
# count   19922.000000      19922.000000
# mean     2979.206104       1973.401767
# std      9009.639341       7333.586040
# min        35.000000         35.000000
# 25%       666.000000        350.000000
# 50%      1040.000000        550.000000
# 75%      1999.000000        999.000000
# max    571230.000000     571230.000000

# %% [markdown]
# ##### To perform statistical functions for the dataset ,we use sample describe function.

# %%
sample['product_name'].value_counts()
# Out:
# TheLostPuppy Back Cover for Apple iPad Air                               134
# TheLostPuppy Back Cover for Apple iPad Air 2                              95
# S4S Stylish Women's Push-up Bra                                           94
# Voylla Metal, Alloy Necklace                                              66
# WallDesign Small Vinyl Sticker                                            65
#                                                                         ...
# Naxa Electronics Naxa Ne-929 Wh Headphones () Headphones                   1
# Kanu Book Cover for Champion Wtab 705 7 inch                               1
# TIGI BED HEAD COLOUR GODDESS OIL INFUSED CONDITIONER                       1
# Takspin casual collection of clutcher & hair pin (set of 7) Hair Claw      1
# Uberlyfe Extra Large Vinyl Sticker                                         1
# Name: product_name, Length: 12676, dtype: int64

# %% [markdown]
# ##### Value.counts function is used to count the values in the Variables with their Data type and Int64

# %%
sample.drop_duplicates(inplace=True)

# %% [markdown]
# ##### In order to Display the duplicates in our dataset

# %%
sample
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# ...

# %%
sample_subset=sample[['retail_price','discounted_price']]

# %% [markdown]
# ##### By using the sample_subset function we can get subset of the dataset.

# %%
sample_subset
# Out:
#        retail_price  discounted_price
# 0             999.0             379.0
# 1           32157.0           22646.0
# 2             999.0             499.0
# 3             699.0             267.0
# 4             220.0             210.0
# ...             ...               ...
# 19995        1500.0             730.0
# 19996        1429.0            1143.0
# 19997        1299.0             999.0
# 19998        1499.0            1199.0
# 19999        1499.0             999.0
#
# [20000 rows x 2 columns]

# %%
sample['Savings']=sample['retail_price']-sample['discounted_price']

# %% [markdown]
# ##### By using this function we can add an another variable in the dataset

# %%
sample
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# ...

# %%
sample_row=sample[sample['Savings']>500]

# %%
sample_row
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 6      ce5a6818f7707e2cb61fdcdbba61f5ad  2016-03-25 22:59:23 +0000
# 7      8542703ca9e6ebdf6d742638dfb1f2ca  2016-03-25 22:59:23 +0000
# 9      4044c0ac52c1ee4b28777417651faf42  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19986  685191121dc0b76fd58cbea81d0019ef  2015-12-01 10:15:43 +0000
# 19987  d359f1bb61997f20ce873f7092998edd  2015-12-01 10:15:43 +0000
# 19988  9d015eb2ac7ca051e16c733c9f0a0b96  2015-12-01 10:15:43 +0000
# 19991  4b4714b5f0c9971d1145efe8d16c458b  2015-12-01 10:15:43 +0000
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
#
#                                         product_name  \
# 0                Alisha Solid Women's Cycling Shorts
# ...

# %%
sample_index=sample.set_index("uniq_id")

# %%
sample_index
# Out:
#                                             crawl_timestamp  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                                     ...
# 7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                                              product_name  \
# uniq_id
# c2d766ca982eca8304150849735ffef9      Alisha Solid Women's Cycling Shorts
# 7f7036a6d550aaa89d34c77bd39a5e48      FabHomeDecor Fabric Double Sofa Bed
# ...

# %% [markdown]
# ##### By using sample index function we can create a space to variable that we are going to assign

# %%
sample_loc=sample.loc[(sample.brand=='Alisha') & (sample.is_FK_Advantage_product=='False')]

# %% [markdown]
# ##### In order to locate a specific data in the dataset by using sample_loc function.

# %%
sample_loc
# Out:
# Empty DataFrame
# Columns: [uniq_id, crawl_timestamp, product_name, product_category_tree, retail_price, discounted_price, is_FK_Advantage_product, product_rating, overall_rating, brand, Savings]
# Index: []

# %%
sample_iloc=sample.iloc[0:10,1:20]

# %%
sample_iloc
# Out:
#              crawl_timestamp  \
# 0  2016-03-25 22:59:23 +0000
# 1  2016-03-25 22:59:23 +0000
# 2  2016-03-25 22:59:23 +0000
# 3  2016-03-25 22:59:23 +0000
# 4  2016-03-25 22:59:23 +0000
# 5  2016-03-25 22:59:23 +0000
# 6  2016-03-25 22:59:23 +0000
# 7  2016-03-25 22:59:23 +0000
# 8  2016-03-25 22:59:23 +0000
# 9  2016-03-25 22:59:23 +0000
#
#                                         product_name  \
# 0                Alisha Solid Women's Cycling Shorts
# 1                FabHomeDecor Fabric Double Sofa Bed
# 2                                         AW Bellies
# 3                Alisha Solid Women's Cycling Shorts
# 4              Sicons All Purpose Arnica Dog Shampoo
# 5  Eternal Gandhi Super Series Crystal Paper Weig...
# 6                Alisha Solid Women's Cycling Shorts
# 7                FabHomeDecor Fabric Double Sofa Bed
# 8  dilli bazaaar Bellies, Corporate Casuals, Casuals
# 9                Alisha Solid Women's Cycling Shorts
#
# ...

# %% [markdown]
# ##### To display a specific number of observations and specific number of variables we use the sample_iloc function.

# %%
sample_agg=sample.groupby('brand')['Savings'].mean()

# %%
sample_agg
# Out:
# brand
# 1OAK             212.000000
# 3D Mat           251.000000
# 3a AUTOCARE      752.608696
# 3a Autocare      867.500000
# 3kFactory        225.000000
#                    ...
# youniqueshop     170.000000
# zDelhi.com       500.000000
# zaidis            21.000000
# zasmina          380.500000
#  Tarkan         1650.000000
# Name: Savings, Length: 3499, dtype: float64

# %% [markdown]
# ##### function where the values of multiple rows are grouped together to form a single summary value.

# %%
sample['product_name']=sample['product_name'].astype('object')

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_name             20000 non-null  object
#  3   product_category_tree    20000 non-null  object
#  4   retail_price             19922 non-null  float64
#  5   discounted_price         19922 non-null  float64
#  6   is_FK_Advantage_product  20000 non-null  bool
#  7   product_rating           20000 non-null  object
#  8   overall_rating           20000 non-null  object
#  9   brand                    14136 non-null  object
#  10  Savings                  19922 non-null  float64
# dtypes: bool(1), float64(3), object(7)
# memory usage: 1.7+ MB

# %% [markdown]
# ##### If we want to change datatype of variable , we use .astype function to change it.

# %%
sample_index=sample.reset_index()

# %%
sample
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# ...

# %% [markdown]
# ##### reset_index() function sets a list of integer ranging from 0 to length of data as index.
